# %% [markdown]
# <a href="https://colab.research.google.com/github/TheCraw08/ConradWilson_TCS/blob/main/Conrad_Wilson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("chicago_traffic_crashes_clean.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24896 entries, 0 to 24895
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH_RECORD_ID                24896 non-null  object
#  1   CRASH_DATE                     24896 non-null  object
#  2   POSTED_SPEED_LIMIT             24896 non-null  int64
#  3   TRAFFIC_CONTROL_DEVICE         24896 non-null  object
#  4   DEVICE_CONDITION               24895 non-null  object
#  5   WEATHER_CONDITION              24895 non-null  object
#  6   LIGHTING_CONDITION             24895 non-null  object
#  7   FIRST_CRASH_TYPE               24895 non-null  object
#  8   TRAFFICWAY_TYPE                24895 non-null  object
#  9   ALIGNMENT                      24895 non-null  object
#  10  ROADWAY_SURFACE_COND           24895 non-null  object
#  11  ROAD_DEFECT                    24895 non-null  object
#  12  REPORT_TYPE                    23692 non-null  object
#  13  CRASH_TYPE                     24895 non-null  object
#  14  INTERSECTION_RELATED_I         5687 non-null   object
#  15  NOT_RIGHT_OF_WAY_I             961 non-null    object
#  16  HIT_AND_RUN_I                  7882 non-null   object
#  17  DAMAGE                         24895 non-null  object
#  18  PRIM_CONTRIBUTORY_CAUSE        24895 non-null  object
#  19  STREET_NO                      24895 non-null  float64
#  20  STREET_DIRECTION               24895 non-null  object
#  21  STREET_NAME                    24895 non-null  object
#  22  BEAT_OF_OCCURRENCE             24895 non-null  float64
#  23  NUM_UNITS                      24895 non-null  float64
#  24  CRASH_MONTH                    24895 non-null  float64
#  25  MOST_SEVERE_INJURY             24855 non-null  object
#  26  INJURIES_TOTAL                 24855 non-null  float64
#  27  INJURIES_FATAL                 24855 non-null  float64
#  28  INJURIES_INCAPACITATING        24855 non-null  float64
#  29  INJURIES_NON_INCAPACITATING    24855 non-null  float64
#  30  INJURIES_REPORTED_NOT_EVIDENT  24855 non-null  float64
#  31  INJURIES_NO_INDICATION         24855 non-null  float64
#  32  INJURIES_UNKNOWN               24855 non-null  float64
#  33  CRASH_HOUR                     24895 non-null  float64
#  34  CRASH_DAY_OF_WEEK              24895 non-null  float64
#  35  LATITUDE                       24648 non-null  float64
#  36  LONGITUDE                      24648 non-null  float64
# dtypes: float64(15), int64(1), object(21)
# memory usage: 7.0+ MB

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['CRASH_RECORD_ID', 'CRASH_DATE', 'POSTED_SPEED_LIMIT',
#        'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION', 'WEATHER_CONDITION',
#        'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE',
#        'ALIGNMENT', 'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'REPORT_TYPE',
#        'CRASH_TYPE', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I',
#        'HIT_AND_RUN_I', 'DAMAGE', 'PRIM_CONTRIBUTORY_CAUSE', 'STREET_NO',
#        'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE', 'NUM_UNITS',
#        'CRASH_MONTH', 'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL',
#        'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING',
#        'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION',
#        'INJURIES_UNKNOWN', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')
